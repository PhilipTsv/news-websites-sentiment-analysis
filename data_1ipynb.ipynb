# %%
import requests
import urllib3
import json
from lxml import html, etree
import requests.packages.urllib3.exceptions
from urllib3.exceptions import InsecureRequestWarning

# %%
def getRequest(url):
    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-GB,en;q=0.9,en-US;q=0.8,ml;q=0.7',
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36'
    }
    requests.packages.urllib3.disable_warnings(InsecureRequestWarning)
    response = requests.get(url, verify=False, headers=headers)
    return response.text

# %%
urlsList = [('China', 'https://www.theguardian.com/world/china')]

# %%
urls = []
for urlPair in urlsList:
  #https://www.theguardian.com/world/china?page=1097
  for i in range(0, 1097):
    url = urlPair[1]
    pagesParser = html.fromstring(getRequest(url))

    page = i
    #https://www.theguardian.com/world/china?page=1000
    parser = html.fromstring(getRequest(url + "?page=" + str(page)))

    #<div class="fc-item__content "> 
    items = parser.xpath("//div[@class='fc-item__content ']")

    for item in items:
      for elt in item.xpath(".//h3[@class='fc-item__title']"):
        urls.append(elt[0].attrib['href'])

print(urls)
# Out:
# ['https://www.theguardian.com/technology/2021/apr/07/china-bitcoin-mining-climate-targets-nature-study', 'https://www.theguardian.com/commentisfree/2021/apr/06/the-guardian-view-on-the-pandemic-a-universal-crisis-is-revealing-our-divisions', 'https://www.theguardian.com/us-news/2021/apr/06/donald-trump-billionaire-rankings-forbes', 'https://www.theguardian.com/environment/2021/apr/03/china-sandstorms-highlight-threat-of-climate-crisis', 'https://www.theguardian.com/world/2021/apr/03/china-launches-musical-in-bid-to-counter-uyghur-abuse-allegations', 'https://www.theguardian.com/books/video/2021/apr/03/wings-of-song-china-launches-idyllic-musical-set-in-xinjiang-video', 'https://www.theguardian.com/business/2021/apr/02/vw-china-venture-buys-green-credits-from-tesla-to-meet-local-rules', 'https://www.theguardian.com/world/2021/apr/01/hong-kong-democracy-leaders-found-guilty-over-peaceful-2019-protest', 'https://www.theguardian.com/world/2021/apr/01/tiananmen-square-watch-given-chinese-troops-withdrawn-from-sale-fellows-auction-house', 'https://www.theguardian.com/world/2021/apr/01/china-butchers-aesop-fable-in-latest-act-of-wolf-warrior-diplomacy', 'https://www.theguardian.com/australia-news/2021/apr/01/us-has-enormous-respect-for-how-australia-is-standing-up-to-chinas-economic-coercion', 'https://www.theguardian.com/world/2021/mar/31/bbc-journalist-john-sudworth-leaves-china-amid-criticism-of-networks-coverage', 'https://www.theguardian.com/australia-news/